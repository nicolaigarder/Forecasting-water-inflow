# %%
from sympy import *
init_printing()

# %%
import pandas as pd

# File paths
file_path_bygholm = "/Users/nicolaigarderhansen/Desktop/Bachelorprojekt/Data/Nedbor_Dag_Bygholm Skov_DMI.csv"
file_path_hesselballe = "/Users/nicolaigarderhansen/Desktop/Bachelorprojekt/Data/Nedbor_Dag_Hesselballe_DMI.csv"
file_path_korup_parken = "/Users/nicolaigarderhansen/Desktop/Bachelorprojekt/Data/Bygholm_Kørup_Parken_VNF_døgn_1975-2023.csv"

# Read CSVs with correct delimiter and skip headers
bygholm_df = pd.read_csv(file_path_bygholm, skiprows=13, encoding="ISO-8859-1", delimiter=";")
hesselballe_df = pd.read_csv(file_path_hesselballe, skiprows=13, encoding="ISO-8859-1", delimiter=";")
korup_parken_df = pd.read_csv(file_path_korup_parken, decimal=",", encoding="ISO-8859-1", delimiter=";")

# Clean column names (remove leading spaces)
bygholm_df.columns = bygholm_df.columns.str.strip()
hesselballe_df.columns = hesselballe_df.columns.str.strip()
korup_parken_df.columns = korup_parken_df.columns.str.strip()

# Rename columns to match R
bygholm_df.columns = ["timestamp", "NedbørByg", "ksMRK"]
hesselballe_df.columns = ["timestamp", "NedbørHessel", "ksMRK"]
korup_parken_df.columns = ["timestamp", "KarupBro", "BygholmPark"]

# Convert timestamp to datetime format
bygholm_df["timestamp"] = pd.to_datetime(bygholm_df["timestamp"], format="%d-%m-%Y")
hesselballe_df["timestamp"] = pd.to_datetime(hesselballe_df["timestamp"], format="%d-%m-%Y")
korup_parken_df["timestamp"] = pd.to_datetime(korup_parken_df["timestamp"], format="%d-%m-%Y")

# Merge datasets on timestamp (left join)
merged_df = korup_parken_df.copy()
merged_df = merged_df.merge(bygholm_df[["timestamp", "NedbørByg"]], on="timestamp", how="left")
merged_df = merged_df.merge(hesselballe_df[["timestamp", "NedbørHessel"]], on="timestamp", how="left")

# Remove rows where NedbørByg or NedbørHessel is missing
merged_df = merged_df.dropna(subset=["NedbørByg", "NedbørHessel"])

# Create a sequential Time index
merged_df["Time"] = range(len(merged_df))

# reset index
merged_df = merged_df.reset_index(drop=True)

# Display the cleaned and merged dataset
print(shape(merged_df))
merged_df.head()
# Out:
# (5110, 6)
#    timestamp  KarupBro  BygholmPark  NedbørByg  NedbørHessel  Time
# 0 2010-01-04   1806.75          NaN        0.2           0.2     0
# 1 2010-01-05   1676.60          NaN        0.6           0.5     1
# 2 2010-01-06   1562.37          NaN        0.3           0.2     2
# 3 2010-01-07   1427.74          NaN        0.0           0.1     3
# 4 2010-01-08   1280.80          NaN        0.0           0.0     4

# %% [markdown]
# ## Fine-tuning loss function

# %% [markdown]
# ## Fine-tuning Batch-Size

# %% [markdown]
# ## Fine-tuning Learning Rate

# %% [markdown]
# ## Fine-tuning Model Complexity

# %% [markdown]
# ## Evaluation general

# %% [markdown]
# ## Evaluation of extremes

# %%
import itertools
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt

# Define the grid of hyperparameters
hyperparameter_grid = {
    "loss": ["mse", "mae"],
    "batch_size": [8, 16, 32],
    "learning_rate": [0.01, 0.001],
    "lstm_units": [50, 100],
    "layers": [1, 2],
    "time_steps": [5, 10, 20]
}

# Helper functions
def preprocess_data(df, time_steps):
    # Scale features and target
    scaler_X = MinMaxScaler()
    scaler_y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(df[["NedbørByg", "NedbørHessel"]])
    y_scaled = scaler_y.fit_transform(df["KarupBro"].values.reshape(-1, 1))
    
    # Create time-series dataset
    X_series, y_series = [], []
    for i in range(time_steps, len(X_scaled)):
        X_series.append(X_scaled[i - time_steps:i])
        y_series.append(y_scaled[i])
    return np.array(X_series), np.array(y_series), scaler_y

def build_model(time_steps, features, lstm_units, layers, loss, learning_rate):
    model = Sequential()
    for i in range(layers):
        model.add(LSTM(lstm_units, return_sequences=(i < layers - 1), input_shape=(time_steps, features)))
        model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer="adam", loss=loss)
    model.optimizer.lr = learning_rate
    return model

def train_and_evaluate_model(params, X_train, y_train, X_val, y_val, features):
    # Extract parameters
    time_steps = params["time_steps"]
    lstm_units = params["lstm_units"]
    layers = params["layers"]
    loss = params["loss"]
    batch_size = params["batch_size"]
    learning_rate = params["learning_rate"]

    # Build the model
    model = build_model(time_steps, features, lstm_units, layers, loss, learning_rate)

    # Train the model
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=20,  # Reduced for quick testing; can increase for full runs
        batch_size=batch_size,
        verbose=0
    )
    # Return the validation loss from the last epoch
    return history.history["val_loss"][-1], model

# Perform grid search with logging
def full_grid_search_with_logging(df):
    best_loss = float("inf")
    best_params = None
    best_model = None

    # Iterate over all combinations of hyperparameters
    keys, values = zip(*hyperparameter_grid.items())
    total_combinations = len(list(itertools.product(*values)))
    combination_count = 1

    for combination in itertools.product(*values):
        params = dict(zip(keys, combination))
        
        # Preprocess data for current time_steps
        X_series, y_series, scaler_y = preprocess_data(df, params["time_steps"])
        X_train, X_val, y_train, y_val = train_test_split(X_series, y_series, test_size=0.2, shuffle=False)
        features = X_series.shape[2]

        # Train and evaluate the model
        val_loss, model = train_and_evaluate_model(params, X_train, y_train, X_val, y_val, features)

        # Log progress and results
        print(f"Combination {combination_count}/{total_combinations}: {params}")
        print(f"Validation Loss: {val_loss}\n")
        combination_count += 1

        # Track the best parameters
        if val_loss < best_loss:
            best_loss = val_loss
            best_params = params
            best_model = model
    
    return best_params, best_loss, best_model, scaler_y

# grid search with logging
best_params, best_loss, best_model, scaler_y = full_grid_search_with_logging(merged_df)

# Best parameters
print("Best Parameters:", best_params)
print("Best Validation Loss:", best_loss)

# Evaluate and plot predictions using best model
def plot_predictions(best_model, scaler_y, df, time_steps):
    # Prepare test data
    X_series, y_series, _ = preprocess_data(df, time_steps)
    X_train, X_test, y_train, y_test = train_test_split(X_series, y_series, test_size=0.2, shuffle=False)

    # Predict on test data
    y_pred = best_model.predict(X_test)
    y_test_inverse = scaler_y.inverse_transform(y_test)
    y_pred_inverse = scaler_y.inverse_transform(y_pred)

    # Plot results
    plt.figure(figsize=(10, 6))
    plt.plot(y_test_inverse, label="Actual KarupBro")
    plt.plot(y_pred_inverse, label="Predicted KarupBro", linestyle="dashed")
    plt.xlabel("Time Steps")
    plt.ylabel("KarupBro")
    plt.title("Actual vs Predicted KarupBro (Best Model)")
    plt.legend()
    plt.show()

# Plot predictions
plot_predictions(best_model, scaler_y, merged_df, best_params["time_steps"])
# Out:
# Combination 1/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.023716125637292862
#
# Combination 2/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.01751585491001606
#
# Combination 3/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.015984557569026947
#
# Combination 4/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.023089546710252762
#
# Combination 5/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.018409283831715584
#
# Combination 6/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.016071155667304993
#
# Combination 7/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.021021654829382896
#
# Combination 8/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.02074383571743965
#
# Combination 9/144: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0
144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.1062641367316246
#
# Combination 99/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.09424885362386703
#
# Combination 100/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10635097324848175
#
# Combination 101/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.09811656177043915
#
# Combination 102/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.12987330555915833
#
# Combination 103/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.1031542420387268
#
# Combination 104/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.09115010499954224
#
# Combination 105/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.08576285094022751
#
# Combination 106/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10328731685876846
#
# Combination 107/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.1007254496216774
#
# Combination 108/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.1307445615530014
#
# Combination 109/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.1141287237405777
#
# Combination 110/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.09816335141658783
#
# Combination 111/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.08737461268901825
#
# Combination 112/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10922236740589142
#
# Combination 113/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.09974471479654312
#
# Combination 114/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.09546374529600143
#
# Combination 115/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.11233001947402954
#
# Combination 116/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.09934572130441666
#
# Combination 117/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.10252891480922699
#
# Combination 118/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10987958312034607
#
# Combination 119/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.09716449677944183
#
# Combination 120/144: {'loss': 'mae', 'batch_size': 16, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.08619001507759094
#
# Combination 121/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.10627280920743942
#
# Combination 122/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.09069498628377914
#
# Combination 123/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.08530373126268387
#
# Combination 124/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10178183019161224
#
# Combination 125/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.10032246261835098
#
# Combination 126/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 50, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.08435133844614029
#
# Combination 127/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.10238971561193466
#
# Combination 128/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.09820213168859482
#
# Combination 129/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.08934784680604935
#
# Combination 130/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10510670393705368
#
# Combination 131/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.10040611773729324
#
# Combination 132/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.01, 'lstm_units': 100, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.10313288867473602
#
# Combination 133/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.11429094523191452
#
# Combination 134/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.1013820469379425
#
# Combination 135/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.0983579233288765
#
# Combination 136/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.11388348788022995
#
# Combination 137/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.10312961041927338
#
# Combination 138/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 50, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.09271299093961716
#
# Combination 139/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 5}
# Validation Loss: 0.11465775966644287
#
# Combination 140/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 10}
# Validation Loss: 0.10276464372873306
#
# Combination 141/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Validation Loss: 0.09399966150522232
#
# Combination 142/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 5}
# Validation Loss: 0.10726375132799149
#
# Combination 143/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 10}
# Validation Loss: 0.09948804974555969
#
# Combination 144/144: {'loss': 'mae', 'batch_size': 32, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 2, 'time_steps': 20}
# Validation Loss: 0.08130007982254028
#
# Best Parameters: {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}
# Best Validation Loss: 0.014294239692389965
# 32/32 [==============================] - 0s 2ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

# Best Parameters
best_params = {'loss': 'mse', 'batch_size': 8, 'learning_rate': 0.001, 'lstm_units': 100, 'layers': 1, 'time_steps': 20}

# Preprocessing data using the best time_steps
time_steps = best_params["time_steps"]
X_series, y_series, scaler_y = preprocess_data(merged_df, time_steps)
X_train, X_test, y_train, y_test = train_test_split(X_series, y_series, test_size=0.2, shuffle=False)
features = X_series.shape[2]

# Building model with the best parameters
def build_best_model(best_params, features):
    model = Sequential()
    for i in range(best_params["layers"]):
        model.add(LSTM(best_params["lstm_units"], return_sequences=(i < best_params["layers"] - 1),
                       input_shape=(best_params["time_steps"], features)))
        model.add(Dropout(0.2))
    model.add(Dense(1))
    model.compile(optimizer="adam", loss=best_params["loss"])
    model.optimizer.lr = best_params["learning_rate"]
    return model

best_model = build_best_model(best_params, features)

# Train the best model
history = best_model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=best_params["batch_size"],
    verbose=1
)

# Predict on test set
y_pred = best_model.predict(X_test)
y_test_inverse = scaler_y.inverse_transform(y_test)
y_pred_inverse = scaler_y.inverse_transform(y_pred)

# Evaluate on all data (General MAE)
general_mae = mean_absolute_error(y_test_inverse, y_pred_inverse)
print(f"General MAE: {general_mae}")

# Evaluate on extreme cases
extreme_threshold = np.percentile(y_test_inverse, 90)  # Top 10% as extremes
extreme_indices = y_test_inverse.flatten() >= extreme_threshold
extreme_mae = mean_absolute_error(y_test_inverse[extreme_indices], y_pred_inverse[extreme_indices])
print(f"Extreme MAE: {extreme_mae}")

# Plot predictions vs actual values for extremes
plt.figure(figsize=(10, 6))
plt.plot(y_test_inverse[extreme_indices], label="Actual KarupBro (Extremes)", marker="o")
plt.plot(y_pred_inverse[extreme_indices], label="Predicted KarupBro (Extremes)", marker="x")
plt.xlabel("Extreme Instances")
plt.ylabel("KarupBro")
plt.title("Actual vs Predicted KarupBro (Extremes)")
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 509/509 [==============================] - 3s 4ms/step - loss: 0.0271 - val_loss: 0.0270
# Epoch 2/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0253 - val_loss: 0.0248
# Epoch 3/50
# 509/509 [==============================] - 2s 4ms/step - loss: 0.0250 - val_loss: 0.0239
# Epoch 4/50
# 509/509 [==============================] - 2s 4ms/step - loss: 0.0248 - val_loss: 0.0261
# Epoch 5/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0245 - val_loss: 0.0248
# Epoch 6/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0245 - val_loss: 0.0227
# Epoch 7/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0239 - val_loss: 0.0222
# Epoch 8/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0235 - val_loss: 0.0188
# Epoch 9/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0231 - val_loss: 0.0193
# Epoch 10/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0225 - val_loss: 0.0178
# Epoch 11/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0225 - val_loss: 0.0175
# Epoch 12/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0219 - val_loss: 0.0187
# Epoch 13/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0215 - val_loss: 0.0179
# Epoch 14/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0213 - val_loss: 0.0163
# Epoch 15/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0210 - val_loss: 0.0145
# Epoch 16/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0206 - val_loss: 0.0155
# Epoch 17/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0201 - val_loss: 0.0163
# Epoch 18/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0201 - val_loss: 0.0137
# Epoch 19/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0199 - val_loss: 0.0142
# Epoch 20/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0196 - val_loss: 0.0157
# Epoch 21/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0195 - val_loss: 0.0139
# Epoch 22/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0191 - val_loss: 0.0169
# Epoch 23/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0188 - val_loss: 0.0177
# Epoch 24/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0184 - val_loss: 0.0188
# Epoch 25/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0181 - val_loss: 0.0189
# Epoch 26/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 27/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 28/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0176 - val_loss: 0.0187
# Epoch 29/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0175 - val_loss: 0.0173
# Epoch 30/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0171 - val_loss: 0.0185
# Epoch 31/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0172 - val_loss: 0.0178
# Epoch 32/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0170 - val_loss: 0.0189
# Epoch 33/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0167 - val_loss: 0.0179
# Epoch 34/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0167 - val_loss: 0.0182
# Epoch 35/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0164 - val_loss: 0.0178
# Epoch 36/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0162 - val_loss: 0.0186
# Epoch 37/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0159 - val_loss: 0.0192
# Epoch 38/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0154 - val_loss: 0.0199
# Epoch 39/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0156 - val_loss: 0.0198
# Epoch 40/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0153 - val_loss: 0.0178
# Epoch 41/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0153 - val_loss: 0.0204
# Epoch 42/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0150 - val_loss: 0.0155
# Epoch 43/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0145 - val_loss: 0.0188
# Epoch 44/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0146 - val_loss: 0.0196
# Epoch 45/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0145 - val_loss: 0.0162
# Epoch 46/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0141 - val_loss: 0.0177
# Epoch 47/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0138 - val_loss: 0.0167
# Epoch 48/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0134 - val_loss: 0.0172
# Epoch 49/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0133 - val_loss: 0.0197
# Epoch 50/50
# 509/509 [==============================] - 2s 3ms/step - loss: 0.0130 - val_loss: 0.0190
# 32/32 [==============================] - 0s 2ms/step
# General MAE: 904.5755638693826
# Extreme MAE: 1706.8170988913141
